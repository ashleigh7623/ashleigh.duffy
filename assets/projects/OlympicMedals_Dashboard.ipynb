# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')
import ipywidgets as widgets

import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='c6e4e5dc-38a1-42ff-931d-f9faeeffe24e'>
#   <div id="bfca966a-effa-4d9a-96e2-9a17ca667227" data-root-id="c6e4e5dc-38a1-42ff-931d-f9faeeffe24e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"93d0927a-b90a-41e9-9e5f-9cdbf845a89d":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"c6e4e5dc-38a1-42ff-931d-f9faeeffe24e"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"d59a4916-25d1-4828-a1ed-b4f96b2722a4","attributes":{"plot_id":"c6e4e5dc-38a1-42ff-931d-f9faeeffe24e","comm_id":"cc13cd0ee5bd448a8a313102c6f81615","client_comm_id":"eee2f2dbaf1244a282b02e4fa815db41"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"93d0927a-b90a-41e9-9e5f-9cdbf845a89d","roots":{"c6e4e5dc-38a1-42ff-931d-f9faeeffe24e":"bfca966a-effa-4d9a-96e2-9a17ca667227"},"root_ids":["c6e4e5dc-38a1-42ff-931d-f9faeeffe24e"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# cache data to improve dashboard performance
if 'data' not in pn.state.cache.keys():

    df = pd.read_csv('C:/Users/ash/Downloads/olympics_dataset_up.csv') 
    df.columns = map(str.lower, df.columns)
    df['continent'] = df['continent'].fillna('Other')
    df['year'] = df['year'].astype(int)
    pn.state.cache['data'] = df.copy()

else: 

    df = pn.state.cache['data']

# %% [markdown]
# # Minor Data Preprocessing

# %%
# Fill NAs with 0s and create GDP per capita column
df = df.fillna(0)

# %%
# Make DataFrame Pipeline Interactive
idf = df.interactive()

# %% [markdown]
# # Visual 1: Olympic Medals Over Time by Continent

# %%
# Define Panel widgets
year_slider = pn.widgets.IntSlider(name='Year Slider', start=1895, end=2025, step=1, value=1895)
year_slider
# Out:
# IntSlider(end=2025, name='Year Slider', start=1895, value=1895)

# %%
# Radio buttons for CO2 measures
yaxis_medal_cnt = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['count_medals', 'cnt_gold'],
    button_type='success'
)

# %%
continents = ['Other', 'Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

medal_pipeline = (
    idf[
        (idf.year <= year_slider) &
        (idf.continent.isin(continents))
    ]
    .groupby(['continent', 'year'])[yaxis_medal_cnt].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
medal_pipeline
# Out:
# <div id='cabe5934-5e37-4dfe-aa72-55a9d6308e56'>
#   <div id="f636030f-488c-4998-93a0-58b5738d6f0c" data-root-id="cabe5934-5e37-4dfe-aa72-55a9d6308e56" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"422ec90d-bc4e-4170-a174-e58b955194bb":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"cabe5934-5e37-4dfe-aa72-55a9d6308e56","attributes":{"name":"Row02593","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"e8c4c875-3010-457e-96ee-bd9a0e35330d","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"79bbf00b-7670-4c14-a72b-ebab7ad4a817","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"0f5391be-0112-4cf4-bdac-d97767779a32","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"5cb7d041-8195-47d0-b33b-288836ab3094","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"99f1bd64-31b1-4fb3-b689-2109582762ce","attributes":{"name":"Column02592","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"e8c4c875-3010-457e-96ee-bd9a0e35330d"},{"id":"79bbf00b-7670-4c14-a72b-ebab7ad4a817"},{"id":"0f5391be-0112-4cf4-bdac-d97767779a32"},{"id":"5cb7d041-8195-47d0-b33b-288836ab3094"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"b723a290-77a9-4ebc-87ba-df5895d46722","attributes":{"name":"Column02584","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"e8c4c875-3010-457e-96ee-bd9a0e35330d"},{"id":"79bbf00b-7670-4c14-a72b-ebab7ad4a817"},{"id":"0f5391be-0112-4cf4-bdac-d97767779a32"},{"id":"5cb7d041-8195-47d0-b33b-288836ab3094"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"f8d87296-494e-4edc-8d22-d92f7f7c3f83","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"e8c4c875-3010-457e-96ee-bd9a0e35330d"},{"id":"0f5391be-0112-4cf4-bdac-d97767779a32"},{"id":"5cb7d041-8195-47d0-b33b-288836ab3094"}],"margin":[5,10],"align":"start","title":"Year Slider","start":1895,"end":2025,"value":1928}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"5952eac7-3486-4f18-90e0-25f7483b8fd9","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"e8c4c875-3010-457e-96ee-bd9a0e35330d"},{"type":"object","name":"ImportedStyleSheet","id":"020356a8-2c62-4b98-ae54-2db322b5ed9b","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/button.css"}},{"id":"0f5391be-0112-4cf4-bdac-d97767779a32"},{"id":"5cb7d041-8195-47d0-b33b-288836ab3094"}],"margin":[5,10],"align":"start","labels":["count_medals","cnt_gold"],"active":0}}]}},{"type":"object","name":"panel.models.layout.Column","id":"2aaa78fb-2041-4a11-ac91-80e851cf7c6b","attributes":{"name":"Column02589","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"e8c4c875-3010-457e-96ee-bd9a0e35330d"},{"id":"79bbf00b-7670-4c14-a72b-ebab7ad4a817"},{"id":"0f5391be-0112-4cf4-bdac-d97767779a32"},{"id":"5cb7d041-819 ...

# %%
medal_plot = medal_pipeline.hvplot(x = 'year', by='continent', y=yaxis_medal_cnt,line_width=2, title="Medal Count by Continent")
medal_plot
# Out:
# <div id='2ed44a83-d574-45e6-98e1-c332712c61ff'>
#   <div id="e4bec5e6-14de-49b0-95a0-57da51388f50" data-root-id="2ed44a83-d574-45e6-98e1-c332712c61ff" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"3aeda659-75d4-49f4-9c65-0ba03712160a":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"2ed44a83-d574-45e6-98e1-c332712c61ff","attributes":{"name":"Row02866","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"a2eae7ce-980b-4e4e-95a1-0d64bab0c747","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"cf2dec8f-46ea-45dc-94d1-6e814ea85ec8","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"7932df58-20a0-4369-b61f-2266326b5c1f","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"e583b5ba-635e-4a03-b30b-b3517ae432b1","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"66f3031d-a227-4d1e-b66d-166f9219187e","attributes":{"name":"Column02865","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"a2eae7ce-980b-4e4e-95a1-0d64bab0c747"},{"id":"cf2dec8f-46ea-45dc-94d1-6e814ea85ec8"},{"id":"7932df58-20a0-4369-b61f-2266326b5c1f"},{"id":"e583b5ba-635e-4a03-b30b-b3517ae432b1"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"41afcf42-f75b-4c5f-80a3-11ca15ed6a9a","attributes":{"name":"Column02856","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"a2eae7ce-980b-4e4e-95a1-0d64bab0c747"},{"id":"cf2dec8f-46ea-45dc-94d1-6e814ea85ec8"},{"id":"7932df58-20a0-4369-b61f-2266326b5c1f"},{"id":"e583b5ba-635e-4a03-b30b-b3517ae432b1"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"eb457b14-8f4b-461b-9e65-3db61e34941b","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"a2eae7ce-980b-4e4e-95a1-0d64bab0c747"},{"id":"7932df58-20a0-4369-b61f-2266326b5c1f"},{"id":"e583b5ba-635e-4a03-b30b-b3517ae432b1"}],"margin":[5,10],"align":"start","title":"Year Slider","start":1895,"end":2025,"value":1928}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"4ca0d81c-f99e-4e8b-9148-4e16f571cda5","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"a2eae7ce-980b-4e4e-95a1-0d64bab0c747"},{"type":"object","name":"ImportedStyleSheet","id":"0c3b4e67-b64f-4c70-b8e6-6b5a4d622140","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/button.css"}},{"id":"7932df58-20a0-4369-b61f-2266326b5c1f"},{"id":"e583b5ba-635e-4a03-b30b-b3517ae432b1"}],"margin":[5,10],"align":"start","labels":["count_medals","cnt_gold"],"active":0}}]}},{"type":"object","name":"Figure","id":"0996b35c-f5f4-491c-b90e-b690829c97d2","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"8784b08a-fac7-4f52-8453-1239bc67afdc","attributes":{"tags":[[["year",null]],[]],"start":1896.0,"end":1928.0,"reset_start":1896.0,"reset_end":1928.0}},"y_range":{"type":"object","name":"Range1d","id":"46a0747d-bce0-456c-8fa7-558ffc001e9f","attributes":{"tags":[[ ...

# %% [markdown]
# # Visual 2: Medals over time by continent

# %%
continents = ['Other', 'Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']
medal_pipeline_yr = (
    idf[
        (idf.year == year_slider) &
        (idf.continent.isin(continents))
    ]
    .groupby(['continent', 'year'])[yaxis_medal_cnt].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
medal_table = medal_pipeline_yr.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width', index=No ) 

medal_table
# Out:
# <div id='06168c7d-bcb4-413e-9dd8-81de799337b8'>
#   <div id="f335ccf9-e151-4d8e-819c-dc8a618264f1" data-root-id="06168c7d-bcb4-413e-9dd8-81de799337b8" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f895c686-22c7-4a15-b785-a8a949c3d4fe":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"06168c7d-bcb4-413e-9dd8-81de799337b8","attributes":{"name":"Row04088","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"07abee16-8852-43ef-b274-780a74752141","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"dd4582ae-4afb-4569-a5df-db4eeef72e96","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"e20b477e-caba-40a0-a708-70bce0e3959e","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"59952c50-04d9-49ab-aa8a-1ef0c5074422","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/native.css"}}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"73ef4072-5282-44e8-a977-b78edadb21b1","attributes":{"name":"Column04087","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"07abee16-8852-43ef-b274-780a74752141"},{"id":"dd4582ae-4afb-4569-a5df-db4eeef72e96"},{"id":"e20b477e-caba-40a0-a708-70bce0e3959e"},{"id":"59952c50-04d9-49ab-aa8a-1ef0c5074422"}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"6253684d-4b32-40b4-b363-6eb594d386d1","attributes":{"name":"Column04081","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"07abee16-8852-43ef-b274-780a74752141"},{"id":"dd4582ae-4afb-4569-a5df-db4eeef72e96"},{"id":"e20b477e-caba-40a0-a708-70bce0e3959e"},{"id":"59952c50-04d9-49ab-aa8a-1ef0c5074422"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"1c9af53a-5131-4e7b-a369-8a9c919b6960","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"07abee16-8852-43ef-b274-780a74752141"},{"id":"e20b477e-caba-40a0-a708-70bce0e3959e"},{"id":"59952c50-04d9-49ab-aa8a-1ef0c5074422"}],"margin":[5,10],"align":"start","title":"Year Slider","start":1895,"end":2025,"value":1928}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"5daf4b2c-eb25-4323-b1a6-db930b653495","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"07abee16-8852-43ef-b274-780a74752141"},{"type":"object","name":"ImportedStyleSheet","id":"4c763770-ef47-4f7e-aa4f-c1c8d6b751a9","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/button.css"}},{"id":"e20b477e-caba-40a0-a708-70bce0e3959e"},{"id":"59952c50-04d9-49ab-aa8a-1ef0c5074422"}],"margin":[5,10],"align":"start","labels":["count_medals","cnt_gold"],"active":0}}]}},{"type":"object","name":"panel.models.layout.Column","id":"ed665877-e31c-4943-943e-e9236c420317","attributes":{"name":"Column04086","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"07abee16-8852-43ef-b274-780a74752141"},{"id":"dd4582ae-4afb-4569-a5df-db4eeef72e96"},{"id" ...

# %% [markdown]
# # Visual 3: Gold vs All Scatterplot

# %%
continent_level_agg = df.groupby(['continent', 'year'], as_index=False)['count_medals'].sum()

continent_level_agg

idf_agg = continent_level_agg.interactive()

# %%
continents = ['Other', 'Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']


medal_scatterplot_pipeline = (
    idf_agg[
        (idf_agg.year == year_slider) &
          (idf_agg.continent.isin(continents))
       
    ]
    .groupby(['continent', 'year'])['count_medals'].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
medal_scatterplot = medal_scatterplot_pipeline.hvplot(x='count_medals', 
                                                                y='continent', 
                                                                by='continent', 
                                                                size=80, 
                                                                kind="scatter", 
                                                                alpha=0.7,
                                                                legend=False, 
                                                                height=500, 
                                                                width=500)
medal_scatterplot
# Out:
# <div id='2b38c2f1-18f0-4bf2-aec0-cd1c3ee8abb4'>
#   <div id="d80d0a43-87cf-4410-86a1-7b466a9bdec1" data-root-id="2b38c2f1-18f0-4bf2-aec0-cd1c3ee8abb4" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"4ab4ffdc-8393-4688-b43b-7bdf75874d53":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"2b38c2f1-18f0-4bf2-aec0-cd1c3ee8abb4","attributes":{"name":"Row04663","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"d808d275-6b78-401e-adc6-69bd79bfdf4e","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"bc70c029-6fbe-44f5-8964-0677b6901adc","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"226d56b8-85ad-4036-bf24-fba76ea73bc1","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"51dfbe91-5cae-4ae9-bcdd-36ece057f6e7","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"eb5c7d81-3a83-46cc-902f-e1c4b8b10116","attributes":{"name":"Column04662","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"d808d275-6b78-401e-adc6-69bd79bfdf4e"},{"id":"bc70c029-6fbe-44f5-8964-0677b6901adc"},{"id":"226d56b8-85ad-4036-bf24-fba76ea73bc1"},{"id":"51dfbe91-5cae-4ae9-bcdd-36ece057f6e7"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"7f28adb6-dc98-4793-8ef4-0616d126ef81","attributes":{"name":"Column04653","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"d808d275-6b78-401e-adc6-69bd79bfdf4e"},{"id":"bc70c029-6fbe-44f5-8964-0677b6901adc"},{"id":"226d56b8-85ad-4036-bf24-fba76ea73bc1"},{"id":"51dfbe91-5cae-4ae9-bcdd-36ece057f6e7"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"f4aa321d-432c-4072-881d-ff56610f9312","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"d808d275-6b78-401e-adc6-69bd79bfdf4e"},{"id":"226d56b8-85ad-4036-bf24-fba76ea73bc1"},{"id":"51dfbe91-5cae-4ae9-bcdd-36ece057f6e7"}],"margin":[5,10],"align":"start","title":"Year Slider","start":1895,"end":2025,"value":1928}}]}},{"type":"object","name":"Figure","id":"e6af3439-08d5-4e79-a950-ceec25851b47","attributes":{"width":500,"height":500,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"89fdfde7-87d4-49a2-92bc-f4d75f2ab8bd","attributes":{"tags":[[["count_medals",null]],[]],"start":-35.7,"end":452.7,"reset_start":-35.7,"reset_end":452.7}},"y_range":{"type":"object","name":"FactorRange","id":"e312cb1e-2d21-4fc4-8bf5-7f64ec372826","attributes":{"tags":[[["continent",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"factors":["Africa","Asia","Europe","North America","Oceania","Other","South America"]}},"x_scale":{"type":"object","name":"LinearScale","id":"6335bac7-9224-41ef-a1d6-07fa064eb618"},"y_scale":{"type":"object","name":"CategoricalScale","id":"717900fb-a220-4b81-8e0e-5f2b7579cc28"},"title":{"type":"object","name":"Title","id":"4e412b6c-d5e3-48c7-a555-458dd2d67f49","attributes":{"text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object","name":"GlyphRenderer","id":"0ced8597-0bf5-47fc-a3a2-fcfbd661d976","attributes":{"data_source":{"type":"object","name":"ColumnDataSource","id":"b00bc4e1-9aee-48f7-80d7-183727885d46","attributes":{"s ...

# %% [markdown]
# # Visual 4: Bar Chart with Medals by Continent

# %%
yaxis_medal_source = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['cnt_gold', 'cnt_silver', 'cnt_bronze'], 
    button_type='success'
)

continents_excl_world = ['Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

medal_source_bar_pipeline = (
    idf[
        (idf.year == year_slider) &
        (idf.continent.isin(continents_excl_world))
    ]
    .groupby(['year', 'continent'])[yaxis_medal_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

medal_source_bar_pipeline
# Out:
# <div id='684b88a9-c940-45a7-889e-b4328d246022'>
#   <div id="ae88fbf1-e769-4831-a99c-338f4845439e" data-root-id="684b88a9-c940-45a7-889e-b4328d246022" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"2bf6ce5a-ff27-412d-b8be-21e34d2b0199":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"684b88a9-c940-45a7-889e-b4328d246022","attributes":{"name":"Row05530","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"c46b8829-8a6c-4213-80f9-ea99d4e8776d","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"49c762c1-ee61-44f4-8e83-cbf8aa9cc327","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"62d77793-35b7-4281-a02d-dfc5c38b8f6b","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"bad50e13-b9fb-43ee-91bf-6ed8806f3529","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"c45e8b67-fa9a-48b7-9968-3623481313ee","attributes":{"name":"Column05529","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"c46b8829-8a6c-4213-80f9-ea99d4e8776d"},{"id":"49c762c1-ee61-44f4-8e83-cbf8aa9cc327"},{"id":"62d77793-35b7-4281-a02d-dfc5c38b8f6b"},{"id":"bad50e13-b9fb-43ee-91bf-6ed8806f3529"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"8115b1f6-6a83-4b21-b364-ad80d01c3a06","attributes":{"name":"Column05521","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"c46b8829-8a6c-4213-80f9-ea99d4e8776d"},{"id":"49c762c1-ee61-44f4-8e83-cbf8aa9cc327"},{"id":"62d77793-35b7-4281-a02d-dfc5c38b8f6b"},{"id":"bad50e13-b9fb-43ee-91bf-6ed8806f3529"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"eb27b0f5-c7bc-4e2f-91ea-91f72eb35bba","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"c46b8829-8a6c-4213-80f9-ea99d4e8776d"},{"id":"62d77793-35b7-4281-a02d-dfc5c38b8f6b"},{"id":"bad50e13-b9fb-43ee-91bf-6ed8806f3529"}],"margin":[5,10],"align":"start","title":"Year Slider","start":1895,"end":2025,"value":1928}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"e81eb790-a22b-4240-8f6a-aaaf0317a85a","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"c46b8829-8a6c-4213-80f9-ea99d4e8776d"},{"type":"object","name":"ImportedStyleSheet","id":"0de74603-175d-423f-9cb5-606de6fdb5d4","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/button.css"}},{"id":"62d77793-35b7-4281-a02d-dfc5c38b8f6b"},{"id":"bad50e13-b9fb-43ee-91bf-6ed8806f3529"}],"margin":[5,10],"align":"start","labels":["cnt_gold","cnt_silver","cnt_bronze"],"active":0}}]}},{"type":"object","name":"panel.models.layout.Column","id":"87724b5b-ca8d-45f7-94c7-a4d0dd9e3531","attributes":{"name":"Column05526","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"c46b8829-8a6c-4213-80f9-ea99d4e8776d"},{"id":"49c762c1-ee61-44f4-8e83-cbf8aa9cc327"},{"id":"62d77793-35b7-4281-a02d-dfc5c38b8f6b"},{"id":"b ...

# %%
medal_source_bar_plot = medal_source_bar_pipeline.hvplot(kind='bar', 
                                                     x='continent', 
                                                     y=yaxis_medal_source, 
                                                     title='Medals by continent')
medal_source_bar_plot
# Out:
# <div id='a1d59f39-fa74-4bc6-9003-fca5efe815cc'>
#   <div id="a5abc4c9-4eaf-4797-a96f-2b6cd6550fda" data-root-id="a1d59f39-fa74-4bc6-9003-fca5efe815cc" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"db04b1a5-7fce-45d8-ada1-375a0071d13b":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"a1d59f39-fa74-4bc6-9003-fca5efe815cc","attributes":{"name":"Row05680","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"bc53851d-4e42-43d5-94aa-71f5fd74934c","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"85134e6a-0697-4306-a4f9-eb21925361a8","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"3c7539fa-14bd-458d-a841-6d56a176e133","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"25343ad7-5fe0-4d46-8c2b-3b53694c736d","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"c130144e-528a-417a-9122-d6959f372f07","attributes":{"name":"Column05679","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"bc53851d-4e42-43d5-94aa-71f5fd74934c"},{"id":"85134e6a-0697-4306-a4f9-eb21925361a8"},{"id":"3c7539fa-14bd-458d-a841-6d56a176e133"},{"id":"25343ad7-5fe0-4d46-8c2b-3b53694c736d"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"13a608a2-951d-4bc6-8f3c-2d0709af9aa7","attributes":{"name":"Column05670","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"bc53851d-4e42-43d5-94aa-71f5fd74934c"},{"id":"85134e6a-0697-4306-a4f9-eb21925361a8"},{"id":"3c7539fa-14bd-458d-a841-6d56a176e133"},{"id":"25343ad7-5fe0-4d46-8c2b-3b53694c736d"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"447c672c-1acb-4c9e-a1e3-e815211dc1f2","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"bc53851d-4e42-43d5-94aa-71f5fd74934c"},{"id":"3c7539fa-14bd-458d-a841-6d56a176e133"},{"id":"25343ad7-5fe0-4d46-8c2b-3b53694c736d"}],"margin":[5,10],"align":"start","title":"Year Slider","start":1895,"end":2025,"value":1928}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"890c21e5-cb71-42e9-ad33-42ac9b9b1496","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"bc53851d-4e42-43d5-94aa-71f5fd74934c"},{"type":"object","name":"ImportedStyleSheet","id":"ad65dbd0-1c4c-464f-9cca-8b769be7bdf6","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/button.css"}},{"id":"3c7539fa-14bd-458d-a841-6d56a176e133"},{"id":"25343ad7-5fe0-4d46-8c2b-3b53694c736d"}],"margin":[5,10],"align":"start","labels":["cnt_gold","cnt_silver","cnt_bronze"],"active":0}}]}},{"type":"object","name":"Figure","id":"5e569c3c-9aa8-4181-b816-87702915ef77","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"FactorRange","id":"c5daf6b1-af4c-45f5-a08b-56eb1db00de7","attributes":{"tags":[[["continent",null]],[]],"factors":["Africa","Asia","Europe","North America","Oceania","South America"]}},"y_range":{"type":"object","name":"Range1d","id":"98c79040-1534-4c0c-bce7-5aa181 ...

# %% [markdown]
# # Creating Dashboard

# %%
#Layout using Template
template = pn.template.FastListTemplate(
    title='Olympics Medals Dashboard', 
    sidebar=[pn.pane.Markdown("# Medals by Continents"), 
             pn.pane.Markdown("#### This data dashboard provides a comprehensive overview of the Olympic medals won by each continent throughout the history of the Games. It visually tracks the distribution and trends of gold, silver, and bronze medals over the years, allowing users to explore the performance and growth of different continents in the global sporting arena. The interactive features enable a summarized analysis of specific time periods, medal counts, and countries within each continent, offering insights into historical achievements and competitive dynamics."), 
             pn.pane.Markdown("###### Continent:'Other' includes players not representing a country and/or countries that are no longer current countries e.g. Austro-Hungarian Empire."),
             pn.pane.PNG('C:/Users/ash/Documents/projects/olympics_dashboard/medal.png', sizing_mode='scale_both'),
             pn.pane.Markdown("## Settings"),   
             year_slider],
    main=[pn.Row(pn.Column(yaxis_medal_cnt, 
                           medal_plot.panel(width=700), margin=(0,25)), 
                           medal_table.panel(width=500)), 
          pn.Row(pn.Column(medal_scatterplot.panel(width=600), margin=(0,25)), 
                 pn.Column(yaxis_medal_source, medal_source_bar_plot.panel(width=600)))],
    accent_base_color="#008000",
    header_background="#008000",
)
template.show()
template.servable()

#pn.serve(template, port=80, websocket_origin=['*'])

#template.save('Olympics_Dashboard')
;
